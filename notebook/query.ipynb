# %%
# %cd "E:/src code 2/python 2/KG"
import json
import pandas as pd
import os

from src.index.entity_extractor import EntityExtractor
from src.utils.config_loader import ConfigLoader
from src.llm.gemini import Gemini_LLM
from src.utils.utils import read_file
import os
from src.utils.type import TYPE_OF_ENTITY_IN_KG, TYPE_OF_JOB, TYPE_OF_JOB_ENTITY, TYPE_OF_CV, TYPE_OF_EDGE
from src.db.neo4j import GraphManager, Node, Edge
from src.query.utils import get_top_similar_node

gm = GraphManager("neo4j://localhost:7687", "neo4j", "123123aA@")
config = ConfigLoader().get_config_from_file(r"E:\src code 2\python 2\Legal_RAG\config\config.yaml")
llm = Gemini_LLM(config=config)

entities = ["Programming Language", "Library", "Software", "Technology", "Task", "Country", "City", "District"]
# Out:
# E:\src code 2\python 2\KG

# %%
folder = "E:/data/cv/"
entity_extractor = EntityExtractor(entities=", ".join(entities), llm=llm, cache_folder=folder)
for file in os.listdir(folder):
    if "raw" in file: continue
    with open(folder + file, 'r', encoding="utf-8") as f:
        data = f.read()
        entities_list, _ = entity_extractor.parse_entities(data)
        list_node = [e.node() for e in entities_list]
        for node in list_node:
            node.label = TYPE_OF_JOB_ENTITY
        cv_node = Node(TYPE_OF_CV, {"name":file[:-4]})
        print(get_top_similar_node(gm, cv_node, list_node, TYPE_OF_JOB))
    break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 12
#      10         node.label = TYPE_OF_JOB_ENTITY
#      11     cv_node = Node(TYPE_OF_CV, {"name":file[:-4]})
# ---> 12     print(get_top_similar_node(gm, cv_node, list_node, TYPE_OF_JOB))
#      13 break
#
# File E:\src code 2\python 2\KG\src\query\utils.py:34, in get_top_similar_node(gm, root_node, neighbor_nodes, label, top_k)
#      31     gm.add_edge(Edge(root_node, node, TYPE_OF_EDGE))
#      33 type_of_node = node.label
# ---> 34 for node_name in get_father_node_name(gm,root_node, num_gen):
#      35     print("father node", node_name)
#      36     gm.add_edge(Edge(root_node, Node(type_of_node, {"name":node_name}), TYPE_OF_EDGE))
#
# File E:\src code 2\python 2\KG\src\db\neo4j.py:251, in GraphManager.jaccard_similarity_top(self, A, label_B, top_n)
#     227 query = f"""
#     228 MATCH (a:`{A.label}` {{name: $name}})
#     229 MATCH (a)-[]-(aNeighbor)
#    (...)
#     248 RETURN otherName, jaccardSim
#     249 """
#     250 with self.driver.session() as session:
# --> 251     result = session.run(query, name=A.properties["name"], top_n=top_n)
#     252     return [(record["otherName"], record["jaccardSim"]) for record in result]
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:328, in Session.run(self, query, parameters, **kwargs)
#     326 bookmarks = self._get_bookmarks()
#     327 parameters = dict(parameters or {}, **kwargs)
# --> 328 self._auto_result._run(
#     329     query,
#     330     parameters,
#     331     self._config.database,
#     332     self._config.impersonated_user,
#     333     self._config.default_access_mode,
#     334     bookmarks,
#     335     self._config.notifications_min_severity,
#     336     self._config.notifications_disabled_classifications,
#     337 )
#     339 return self._auto_result
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:219, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     216     self._attached = False
#     217     Util.callback(self._on_closed)
# --> 219 self._connection.run(
#     220     query_text,
#     221     parameters=parameters,
#     222     mode=access_mode,
#     223     bookmarks=bookmarks,
#     224     metadata=query_metadata,
#     225     timeout=query_timeout,
#     226     db=db,
#     227     imp_user=imp_user,
#     228     notifications_min_severity=notifications_min_severity,
#     229     notifications_disabled_classifications=notifications_disabled_classifications,
#     230     dehydration_hooks=self._hydration_scope.dehydration_hooks,
#     231     on_success=on_attached,
#     232     on_failure=on_failed_attach,
#     233 )
#     234 self._pull()
#     235 self._connection.send_all()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt5.py:982, in Bolt5x5.run(self, query, parameters, mode, bookmarks, metadata, timeout, db, imp_user, notifications_min_severity, notifications_disabled_classifications, dehydration_hooks, hydration_hooks, **handlers)
#     978 fields = (query, parameters, extra)
#     979 log.debug(
#     980     "[#%04X]  C: RUN %s", self.local_port, " ".join(map(repr, fields))
#     981 )
# --> 982 self._append(
#     983     b"\x10",
#     984     fields,
#     985     Response(self, "run", hydration_hooks, **handlers),
#     986     dehydration_hooks=dehydration_hooks,
#     987 )
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:813, in Bolt._append(self, signature, fields, response, dehydration_hooks)
#     799 def _append(
#     800     self, signature, fields=(), response=None, dehydration_hooks=None
#     801 ):
#     802     """
#     803     Append a message to the outgoing queue.
#     804
#    (...)
#     811         object of type understood by packstream.
#     812     """
# --> 813     self.outbox.append_message(signature, fields, dehydration_hooks)
#     814     self.responses.append(response)
#     815     if response:
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:137, in Outbox.append_message(self, tag, fields, dehydration_hooks)
#     135 def append_message(self, tag, fields, dehydration_hooks):
#     136     with self._buffer.tmp_buffer():
# --> 137         self._packer.pack_struct(tag, fields, dehydration_hooks)
#     138     self._wrap_message()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_codec\packstream\v1\__init__.py:226, in Packer.pack_struct(self, signature, fields, dehydration_hooks)
#     225 def pack_struct(self, signature, fields, dehydration_hooks=None):
# --> 226     self._pack_struct(
#     227         signature,
#     228         fields,
#     229         dehydration_hooks=self._inject_hooks(dehydration_hooks),
#     230     )
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_codec\packstream\v1\__init__.py:243, in Packer._pack_struct(self, signature, fields, dehydration_hooks)
#     241 write(signature)
#     242 for field in fields:
# --> 243     self._pack(field, dehydration_hooks)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_codec\packstream\v1\__init__.py:75, in Packer._pack(self, data, dehydration_hooks)
#      74 def _pack(self, data, dehydration_hooks=None):
# ---> 75     self._py_pack(data, dehydration_hooks)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_codec\packstream\v1\__init__.py:147, in Packer._py_pack(self, value, dehydration_hooks)
#     143             raise TypeError(
#     144                 f"Map keys must be strings, not {type(key)}"
#     145             )
#     146         self._py_pack(key, dehydration_hooks)
# --> 147         self._py_pack(item, dehydration_hooks)
#     149 # Structure
#     150 elif isinstance(value, Structure):
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_codec\packstream\v1\__init__.py:161, in Packer._py_pack(self, value, dehydration_hooks)
#     158         self._py_pack(transformer(value), dehydration_hooks)
#     159         return
# --> 161 raise ValueError(f"Values of type {type(value)} are not supported")
#
# ValueError: Values of type <class 'src.db.neo4j.Node'> are not supported

# %%
list_node
# Out:
# [<src.db.neo4j.Node at 0x2324f72d990>, <src.db.neo4j.Node at 0x2324f802f20>]
