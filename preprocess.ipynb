# %%
# %cd "E:/src code 2/python 2/KG"
# Out:
# E:\src code 2\python 2\KG

# %%
from src.index.entity_extractor import EntityExtractor
from src.utils.config_loader import ConfigLoader
from src.llm.gemini import Gemini_LLM
from src.utils.utils import read_file
import os
config = ConfigLoader().get_config_from_file(r"E:\src code 2\python 2\Legal_RAG\config\config.yaml")
llm = Gemini_LLM(config=config)

# %%
entities = ["Programming Language", "Library", "Software", "Technology", "Task"]
entity_extractor = EntityExtractor(entities=", ".join(entities), llm=llm)

# %%
# data_folder = "E:/data/jd"

# for i, file in enumerate(os.listdir(data_folder)):
#     if "short" in file:
#         entity_extractor.get_entities_include(read_file(data_folder + '/' + file), file)

# %%
cv = """
Phát triển, huấn luyện và triển khai các mô hình AI, ML.
Triển khai các mô hình thu thập, xử lý dữ liệu lớn như OHLCV, Order Book.
Có kinh nghiệm làm việc với MLFlow.
CÓ khả năng làm việc với torch/tensorflow
Triển khai mô hình trên thời gian thực
Đã có kinh nghiệm làm việc với chatbot như LLAMA, BERT.
Địa điểm: quận Hà Đông.
Kinh nghiệm làm việc 2 năm.
"""

cv = """
Phát triển, huấn luyện và triển khai các mô hình AI, ML.
CÓ khả năng làm việc với torch/tensorflow
Triển khai mô hình trên thời gian thực
Đã có kinh nghiệm làm việc với chatbot như LLAMA, BERT.
Địa điểm: quận Hà Đông.
Kinh nghiệm làm việc 2 năm.
"""

# %%
# import chromadb

# client = chromadb.HttpClient(host='localhost', port=8000)
# collection = client.get_or_create_collection(name="chuatebongtoi")
# collection1 = client.get_or_create_collection(name="chuatebongtoi1")

# %%
list_entities = entity_extractor.get_entities_from_cv(cv)
# Out:
# ```
# ##
# ("entity"<|>PYTHON<|>Programming Language<|>A high-level, general-purpose programming language used extensively in AI and machine learning, often paired with libraries like TensorFlow and PyTorch.)
# ##
# ("entity"<|>TENSORFLOW<|>Library<|>An open-source library developed by Google for numerical computation and large-scale machine learning.)
# ##
# ("entity"<|>PYTORCH<|>Library<|>An open-source machine learning library based on Torch, used for building and training neural networks.)
# ##
# ("entity"<|>LLAMA<|>Software<|>A large language model, likely referring to a specific chatbot implementation.)
# ##
# ("entity"<|>BERT<|>Software<|>A transformer-based machine learning model developed by Google for natural language processing tasks.)
# ##
# ("entity"<|>AI Model Development<|>Task<|>The process of designing, training, and deploying artificial intelligence models.)
# ##
# ("entity"<|>ML Model Training<|>Task<|>The process of training machine learning models using data and algorithms.)
# ##
# ("entity"<|>Model Deployment<|>Task<|>The process of deploying trained AI/ML models into a production environment.)
# ##
# ("entity"<|>Real-time Model Deployment<|>Task<|>Deploying models to process data and provide predictions with minimal latency.)
# ##
# ("relationship"<|>PYTHON<|>TENSORFLOW<|>TensorFlow is a library commonly used with Python for AI/ML development.<|>AND)
# ##
# ("relationship"<|>PYTHON<|>PYTORCH<|>PyTorch is a library commonly used with Python for AI/ML development.<|>AND)
# ##
# ("relationship"<|>AI Model Development<|>TENSORFLOW<|>TensorFlow is used for AI model development.<|>AND)
# ##
# ("relationship"<|>AI Model Development<|>PYTORCH<|>PyTorch is used for AI model development.<|>AND)
# ##
# ("relationship"<|>AI Model Development<|>LLAMA<|>LLAMA is an example of an AI model used in chatbot development.<|>AND)
# ##
# ("relationship"<|>AI Model Development<|>BERT<|>BERT is an example of an AI model used in chatbot development.<|>AND)
# ##
# ("relationship"<|>AI Model Development<|>ML Model Training<|>ML model training is a part of AI model development.<|>AND)
# ##
# ("relationship"<|>AI Model Development<|>Model Deployment<|>Model deployment is a part of AI model development.<|>AND)
# ##
# ("relationship"<|>Model Deployment<|>Real-time Model Deployment<|>Real-time model deployment is a specific type of model deployment.<|>AND)
#
# <|COMPLETE|>
# ```

# %%
from src.db.neo4j import GraphManager, Node, Edge
gm = GraphManager("neo4j://localhost:7687", "neo4j", "123123aA@")

# %%
for entity in list_entities:
    entity_node = entity.node()
    print(entity_node.label, entity_node.properties)
# Out:
# Programming Language {'name': 'PYTHON'}
# Library {'name': 'TENSORFLOW'}
# Library {'name': 'PYTORCH'}
# Software {'name': 'LLAMA'}
# Software {'name': 'BERT'}
# Task {'name': 'AI Model Development'}
# Task {'name': 'ML Model Training'}
# Task {'name': 'Model Deployment'}
# Task {'name': 'Real-time Model Deployment'}

# %%
print(list_entities[0].label, list_entities[0].properties)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(list_entities[0].label, list_entities[0].properties)
#
# AttributeError: 'Entity' object has no attribute 'label'

# %%
for node_relation in gm.get_related_nodes(list_entities[0].node()):
    node = node_relation.node
    print(node.label, node.properties)
# Out:
# ---------------------------------------------------------------------------
# GqlError                                  Traceback (most recent call last)
# GqlError: {gql_status: 42I06} {gql_status_description: error: syntax error or access rule violation - invalid input. Invalid input 'Language', expected: a parameter, '&', ')', ':', 'WHERE', '{' or '|'.} {message: 42I06: Invalid input 'Language', expected: a parameter, '&', ')', ':', 'WHERE', '{' or '|'.} {diagnostic_record: {'_classification': 'CLIENT_ERROR', '_position': {'line': 2, 'column': 30, 'offset': 30}, 'OPERATION': '', 'OPERATION_CODE': '0', 'CURRENT_SCHEMA': '/'}} {raw_classification: CLIENT_ERROR}
#
# The above exception was the direct cause of the following exception:
#
# CypherSyntaxError                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 for node_relation in gm.get_related_nodes(list_entities[0].node()):
#       2     node = node_relation.node
#       3     print(node.label, node.properties)
#
# File e:\src code 2\python 2\KG\src\db\neo4j.py:135, in GraphManager.get_related_nodes(self, node)
#     133 related_nodes = []
#     134 with self.driver.session() as session:
# --> 135     result = session.run(query, name=process_string(node.properties["name"]))
#     136     for record in result:
#     137         related_node = Node(label=record["label"], properties=dict(record["node"]))
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\session.py:328, in Session.run(self, query, parameters, **kwargs)
#     326 bookmarks = self._get_bookmarks()
#     327 parameters = dict(parameters or {}, **kwargs)
# --> 328 self._auto_result._run(
#     329     query,
#     330     parameters,
#     331     self._config.database,
#     332     self._config.impersonated_user,
#     333     self._config.default_access_mode,
#     334     bookmarks,
#     335     self._config.notifications_min_severity,
#     336     self._config.notifications_disabled_classifications,
#     337 )
#     339 return self._auto_result
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:236, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     234 self._pull()
#     235 self._connection.send_all()
# --> 236 self._attach()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\work\result.py:430, in Result._attach(self)
#     428 if self._exhausted is False:
#     429     while self._attached is False:
# --> 430         self._connection.fetch_message()
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:184, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     182 def inner(*args, **kwargs):
#     183     try:
# --> 184         func(*args, **kwargs)
#     185     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     186         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt.py:864, in Bolt.fetch_message(self)
#     860 # Receive exactly one message
#     861 tag, fields = self.inbox.pop(
#     862     hydration_hooks=self.responses[0].hydration_hooks
#     863 )
# --> 864 res = self._process_message(tag, fields)
#     865 self.idle_since = monotonic()
#     866 return res
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_bolt5.py:1208, in Bolt5x7._process_message(self, tag, fields)
#    1206 self._enrich_error_diagnostic_record(summary_metadata)
#    1207 try:
# -> 1208     response.on_failure(summary_metadata or {})
#    1209 except (ServiceUnavailable, DatabaseUnavailable):
#    1210     if self.pool:
#
# File c:\Users\ADMIN\AppData\Local\Programs\Python\Python310\lib\site-packages\neo4j\_sync\io\_common.py:254, in Response.on_failure(self, metadata)
#     252 handler = self.handlers.get("on_summary")
#     253 Util.callback(handler)
# --> 254 raise self._hydrate_error(metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'Language': expected a parameter, '&', ')', ':', 'WHERE', '{' or '|' (line 2, column 30 (offset: 30))
# "        MATCH (a:Programming Language {name: $name})-[r]-(b)"
#                               ^}
